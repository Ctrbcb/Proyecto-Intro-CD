# %%
import pandas as pd

worldwide_gni = pd.read_csv("worldwide_gni.csv")
worldwide_gni.head()
# Out:
#        Country         Income group                     Region  \
# 0        Aruba          High income  Latin America & Caribbean
# 1  Afghanistan           Low income                 South Asia
# 2       Angola  Lower middle income         Sub-Saharan Africa
# 3      Albania  Upper middle income      Europe & Central Asia
# 4      Andorra          High income      Europe & Central Asia
#
#   Lending category   1987     1988     1989     1990     1991     1992  ...  \
# 0              NaN    NaN  10360.0  11760.0  12230.0  13190.0  13990.0  ...
# 1              IDA    NaN      NaN      NaN      NaN      NaN      NaN  ...
# 2             IBRD  670.0    650.0    860.0    780.0   1380.0   1170.0  ...
# 3             IBRD  730.0    730.0    760.0    650.0    410.0    280.0  ...
# 4              NaN    NaN      NaN      NaN      NaN      NaN      NaN  ...
#
#       2011     2012     2013     2014     2015     2016     2017    2018  \
# ...

# %%
worldwide_gni.tail()
# Out:
#           Country         Income group                      Region  \
# 212        Kosovo  Upper middle income       Europe & Central Asia
# 213   Yemen, Rep.           Low income  Middle East & North Africa
# 214  South Africa  Upper middle income          Sub-Saharan Africa
# 215        Zambia  Lower middle income          Sub-Saharan Africa
# 216      Zimbabwe  Lower middle income          Sub-Saharan Africa
#
#     Lending category    1987    1988    1989    1990    1991    1992  ...  \
# 212              IDA     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 213              IDA     NaN     NaN     NaN     NaN     NaN   510.0  ...
# 214             IBRD  2210.0  2670.0  2830.0  2860.0  3000.0  3250.0  ...
# 215              IDA   260.0   330.0   400.0   430.0   390.0   360.0  ...
# 216            Blend   700.0   810.0   840.0   860.0   850.0   700.0  ...
#
#        2011    2012    2013    2014    2015    2016    2017    2018    2019  \
# ...

# %%
worldwide_gdp = pd.read_csv("worldwide_gdp.csv")
worldwide_gdp.head()
# Out:
#      Country Name Country Code        Series Name     Series Code  \
# 0     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 1         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 2         Algeria          DZA  GDP (current US$)  NY.GDP.MKTP.CD
# 3  American Samoa          ASM  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
#
#       2010 [YR2010]     2011 [YR2011]     2012 [YR2012]     2013 [YR2013]  \
# 0   15856574731.441  17804292964.1045  20001598505.7042  20561069558.2152
# 1  11926928505.5231  12890765324.2256  12319830252.4768  12776217194.7928
# 2   161207310515.42  200013038488.906  209058991952.125  209755003250.664
# 3         573000000         570000000         640000000         638000000
# 4  3449966856.68832  3629203786.19154  3188808942.56713  3193704343.20627
#
#       2014 [YR2014]     2015 [YR2015]     2016 [YR2016]     2017 [YR2017]  \
# ...

# %%
worldwide_gdp.tail()
# Out:
#                                          Country Name Country Code  \
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 09/15/2021          NaN
#
#     Series Name Series Code 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 266         NaN         NaN           NaN           NaN           NaN
# 267         NaN         NaN           NaN           NaN           NaN
# 268         NaN         NaN           NaN           NaN           NaN
# 269         NaN         NaN           NaN           NaN           NaN
# 270         NaN         NaN           NaN           NaN           NaN
#
#     2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# ...

# %%
worldwide_covid = pd.read_csv("worldwide_covid.csv")
worldwide_covid.head()
# Out:
#                                      Name  WHO Region  \
# Global                                NaN   238521855
# United States of America         Americas    44194808
# India                     South-East Asia    34001743
# Brazil                           Americas    21582738
# The United Kingdom                 Europe     8231441
#
#                           Cases - cumulative total  \
# Global                                 3060.114439
# United States of America              13351.800000
# India                                  2463.890000
# Brazil                                10153.740000
# The United Kingdom                    12125.390000
#
#                           Cases - cumulative total per 100000 population  \
# Global                                                           2824249
# United States of America                                          607541
# India                                                             129862
# ...

# %%
worldwide_covid.tail()
# Out:
#                          Name  WHO Region  Cases - cumulative total  \
# Saint Helena           Africa           0                       0.0
# Tokelau       Western Pacific           0                       0.0
# Tonga         Western Pacific           0                       0.0
# Turkmenistan           Europe           0                       0.0
# Tuvalu        Western Pacific           0                       0.0
#
#               Cases - cumulative total per 100000 population  \
# Saint Helena                                               0
# Tokelau                                                    0
# Tonga                                                      0
# Turkmenistan                                               0
# Tuvalu                                                     0
#
#               Cases - newly reported in last 7 days  \
# Saint Helena                                    0.0
# Tokelau                                         0.0
# ...
